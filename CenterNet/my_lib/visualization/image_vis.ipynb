# %%
from my_lib.path.demo_data_manager import DemoDataManager
from my_lib.visualization.image_vis import show_color_image, show_single_image

# %% [markdown]
# # 1. Show color image

# %%
demo_path_manger = DemoDataManager()
img = demo_path_manger.color_image()
show_color_image(img)

# %%
show_single_image(img)
# Out:
# ---------------------------
# AssertionErrorTraceback (most recent call last)
# <ipython-input-3-46080fdde234> in <module>
# ----> 1 show_single_image(img)
#
# /home/jianglin/workspace/sk/education/modified_centernet/CenterNet/my_lib/visualization/image_vis.py in show_single_image(img, **kwargs)
#     147     elif 3==img.ndim:
#     148         show_color_image(img, **kwargs)
# --> 149     assert 0
#     150
#     151
#
# AssertionError:

# %% [markdown]
# # 2. Show gray image

# %%
from my_lib.path.demo_data_manager import DemoDataManager
from my_lib.visualization.image_vis import show_gray_image
demo_path_manger = DemoDataManager()
img = demo_path_manger.gray_image()
show_gray_image(img)

# %%
show_single_image(img)
# Out:
# ---------------------------
# AssertionErrorTraceback (most recent call last)
# <ipython-input-6-46080fdde234> in <module>
# ----> 1 show_single_image(img)
#
# /home/jianglin/workspace/sk/education/modified_centernet/CenterNet/my_lib/visualization/image_vis.py in show_single_image(img, **kwargs)
#     147     elif 3==img.ndim:
#     148         show_color_image(img, **kwargs)
# --> 149     else:
#     150         assert 0
#     151
#
# AssertionError:
